# %% [markdown]
# Simulation and Modeling Lab
# **Course Code:** CSE 413
# **Name:** Md.Shahriar Hossain Srabon
# **ID:** 0432310005101056
# **Sec:** 7B1; **Batch:** 53
# **Semester:** Spring 2026
# **Assignment No.:** 04

# %% [markdown]
# #Libraries

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns
import random
import math

# %% [markdown]
# # Part 1

# %%
student_id = "0432310005101056"

# Extract R (last two digits)
R = int(student_id[-2:])

# Define new range
range_max = R / 10

# Define new radius
radius = R / 10

# Count letters only (ignore spaces)
num_letters = 23 # Md.Shahriar Hossain Srabon = 23

# Number of random points
n = 200 * num_letters

print("R =", R)
print("Range = [0,", range_max, "]")
print("New Circle Radius =", radius)
print("Number of Letters =", num_letters)
print("Total Random Points =", n)

# Generate random points
x = np.random.uniform(0, range_max, n)
y = np.random.uniform(0, range_max, n)
print(x)
print(y)
# Out:
# R = 56
# Range = [0, 5.6 ]
# New Circle Radius = 5.6
# Number of Letters = 23
# Total Random Points = 4600
# [3.28810173 5.01347731 1.63491583 ... 3.10887155 3.08238038 4.68119861]
# [2.45814723 5.12580558 5.50237528 ... 1.78013427 2.73804591 1.09119932]

# %% [markdown]
# #  Part 2

# %%
# 1. Function to check inside circle
def is_inside_circle(x, y, r):
    return (x**2 + y**2) <= r**2

# 2. Two Random Methods
half = n // 2

inside_count = 0
outside_count = 0

# First Half: random.uniform()
for _ in range(half):
    x = random.uniform(0, range_max)
    y = random.uniform(0, range_max)

    if is_inside_circle(x, y, radius):
        inside_count += 1
    else:
        outside_count += 1

# Second Half: numpy.random.rand()
for _ in range(half):
    x = np.random.rand() * range_max   # scaled to [0, R/10]
    y = np.random.rand() * range_max

    if is_inside_circle(x, y, radius):
        inside_count += 1
    else:
        outside_count += 1

# 3. Final Running Counts
print("Total Points =", n)
print("Points Inside Circle =", inside_count)
print("Points Outside Circle =", outside_count)
# Out:
# Total Points = 4600
# Points Inside Circle = 3621
# Points Outside Circle = 979

# %% [markdown]
# # Part 3

# %%
# Function to run simulation
def run_simulation(n):
    half = n // 2
    inside_count = 0

    # First half - random.uniform()
    for _ in range(half):
        x = random.uniform(0, range_max)
        y = random.uniform(0, range_max)
        if is_inside_circle(x, y, radius):
            inside_count += 1

    # Second half - np.random.rand()
    for _ in range(half):
        x = np.random.rand() * range_max
        y = np.random.rand() * range_max
        if is_inside_circle(x, y, radius):
            inside_count += 1

    # Adjusted π formula
    pi_est = (inside_count / n) * ((range_max**2) / (radius**2))

    error = abs(math.pi - pi_est)

    return inside_count, pi_est, error


# Print Table Header
print("Range Used | Total Points | Points Inside | Estimated Pi | Error from math.pi")
print("-"*75)

# Run 5 simulations
for i in range(1, 6):
    n = n * i
    inside, pi_value, error = run_simulation(n)

    print(f"[0,{range_max}] | {n} | {inside} | {pi_value:.6f} | {error:.6f}")
# Out:
# Range Used | Total Points | Points Inside | Estimated Pi | Error from math.pi
# ---------------------------------------------------------------------------
# [0,5.6] | 4600 | 3587 | 0.779783 | 2.361810
# [0,5.6] | 9200 | 7186 | 0.781087 | 2.360506
# [0,5.6] | 27600 | 21611 | 0.783007 | 2.358585
# [0,5.6] | 110400 | 86613 | 0.784538 | 2.357055
# [0,5.6] | 552000 | 433746 | 0.785772 | 2.355821
